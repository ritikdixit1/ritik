# %% [markdown]
# <a href="https://colab.research.google.com/github/dixitritik17/ritik/blob/master/LungCancerDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

# %%
lc = pd.read_csv("lung_cancer.csv")
lc
# Out:
#            Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0          John         Wick   35       3      5       4       1
# 1          John  Constantine   27      20      2       5       1
# 2        Camela     Anderson   30       0      5       2       0
# 3          Alex       Telles   28       0      8       1       0
# 4         Diego     Maradona   68       4      5       6       1
# 5     Cristiano      Ronaldo   34       0     10       0       0
# 6        Mihail          Tal   58      15     10       0       0
# 7         Kathy        Bates   22      12      5       2       0
# 8        Nicole       Kidman   45       2      6       0       0
# 9           Ray      Milland   52      18      4       5       1
# 10      Fredric        March   33       4      8       0       0
# 11          Yul      Brynner   18      10      6       3       0
# 12         Joan     Crawford   25       2      5       1       0
# ...

# %%
lc.columns
# Out:
# Index(['Name', 'Surname', 'Age', 'Smokes', 'AreaQ', 'Alkhol', 'Result'], dtype='object')

# %%
lc.isnull().sum()
# Out:
# Name       0
# Surname    0
# Age        0
# Smokes     0
# AreaQ      0
# Alkhol     0
# Result     0
# dtype: int64

# %%
lc.Result.value_counts()[0:59].plot(kind='bar')
plt.show()

# %%
lc=lc.drop('Name',axis=1)
lc=lc.drop('Surname',axis=1)

# %%
lc.head()
# Out:
#    Age  Smokes  AreaQ  Alkhol  Result
# 0   35       3      5       4       1
# 1   27      20      2       5       1
# 2   30       0      5       2       0
# 3   28       0      8       1       0
# 4   68       4      5       6       1

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
y=lc['Result']
x=lc.drop(columns=['Result'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1)

# %%
#Import svm model
from sklearn import svm
#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel
#Train the model using the training sets
clf.fit(x_train, y_train)
#Predict the response for test dataset
y_pred = clf.predict(x_test)
#Score/Accuracy
acc_svc=clf.score(x_test, y_test)*100
acc_svc
# Out:
# 100.0

# %%
x_test
# Out:
#     Age  Smokes  AreaQ  Alkhol
# 27   34      12      8       0
# 12   25       2      5       1
# 38   33      25      8       2
# 53   35      20      5       1
# 25   21      20      5       3
# 44   39      15      7       2

# %%
matrix = []
print("Please enter your details: ")
w=[]

print("Age")
w.append(int(input()))

print("Smokes")
w.append(int(input()))

print("AreaQ")
w.append(int(input()))

print("Alcohol")
w.append(int(input()))

matrix.append(w)

y_pred = clf.predict(matrix)
if y_pred==1:
  print("You have LUNG CANCER\n")
  print("Treatments: \n")
  print("1. Quitting smoking tobacco.\n")
  print("2. Surgical removal of a part (lobe) of a lung.\n")
  print("3. Slows cancer cell growth by targeting a cancer cell's distinguishing features or factors.\n")
  print("4. Treatment that uses x-rays and other high-energy rays to kill abnormal cells. \n")

else:
  print("You don't have a LUNG CANCER")
# Out:
# Please enter your details:
# Age
# 52
# Smokes
# 18
# AreaQ
# 4
# Alcohol
# 5
# You have LUNG CANCER
#
# Treatments:
#
# 1. Quitting smoking tobacco.
#
# 2. Surgical removal of a part (lobe) of a lung.
#
# 3. Slows cancer cell growth by targeting a cancer cell's distinguishing features or factors.
#
# 4. Treatment that uses x-rays and other high-energy rays to kill abnormal cells.
