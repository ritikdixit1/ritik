# %%
import matplotlib.pyplot as plt

total_cases = [923280,629095,315341,55255,16306,7857]
exp_labels = ["Europe","North America","Asia","South America","Africa","Oceania"]
plt.axis("equal")

plt.pie(total_cases, shadow=True ,radius=1.5,counterclock=True,center=(40,40))
plt.legend(exp_labels)

plt.show()

# %%
recovered_cases=[240179,47808,154325,9915,3136,4227]
exp_labels1 = ["Europe","North America","Asia","South America","Africa","Oceania"]
plt.axis("equal")
plt.pie(recovered_cases, shadow=True ,radius=1.5,counterclock=True)
plt.legend(exp_labels1)
plt.show()

# %%
death_cases=[81787,25226,11570,2286,840,70]
exp_labels2 = ["Europe","North America","Asia","South America","Africa","Oceania"]
plt.axis("equal")
plt.pie(death_cases, shadow=True ,radius=1.5,counterclock=True)
plt.legend(exp_labels2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16, 6), subplot_kw=dict(aspect="equal"))


data = [923280,629095,315341,55255,16306,7857]
ingredients = ["Europe","North America","Asia","South America","Africa","Oceania"]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)

ingredients1 = ["Europe: 47.4%","North America: 32.3%","Asia :16.2%","South America: 2.8%","Africa: 0.8%","Oceania: 0.4%"]
wedges = ax.pie(data)

ax.legend(ingredients1,title="Continents")

#plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Comparison of Total cases")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16, 6), subplot_kw=dict(aspect="equal"))


data1 = [240179,47808,154325,9915,3136,4227]
ingredients = ["Europe","North America","Asia","South America","Africa","Oceania"]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


wedges = ax.pie(data1)
ingredients2 = ["Europe: 52.3%","North America: 10.4%","Asia :33.6%","South America: 2.2%","Africa: 0.6%","Oceania: 0.9%"]
ax.legend(ingredients2,title="Continents")

#plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Comparison of Recovered cases")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16, 6), subplot_kw=dict(aspect="equal"))


data2 = [81787,25226,11570,2286,840,70]
ingredients = ["Europe","North America","Asia","South America","Africa","Oceania"]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)

ingredients3 = ["Europe: 67.2%","North America: 20.7%","Asia: 9.5%","South America: 1.9%","Africa: 0.7%","Oceania: 0.06%"]
wedges = ax.pie(data2)

ax.legend(ingredients3,title="Continents")

#plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Comparison of Death cases")

plt.show()
